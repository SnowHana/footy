# %%
from datetime import datetime
import io
import requests
import pandas as pd
from pathlib import Path
import time
import os

# %%
BASE_DIR = Path.cwd()

# Build the path to the data directory
DATA_DIR = BASE_DIR.parents[0] / 'transfer_data' 
CLUBS_FILE = 'clubs.csv'
ELOS_FILE = 'club_elos.csv'
# res.to_csv(DATA_DIR / 'club_elos.csv')


filepath=os.path.join(DATA_DIR, CLUBS_FILE)
clubs_df=pd.read_csv(filepath,sep=",",encoding = "UTF-8")
elos_df = pd.read_csv(os.path.join(DATA_DIR, ELOS_FILE), sep=',', encoding='UTF-8')

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
 
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with both keys and matches
    """
    s = df_2[key2].tolist()
 
    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))
    df_1['matches'] = m
 
    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2
 
    return df_1

# %%
# s = elos_df['Club'].tolist()
s = clubs_df['name'].tolist()
s
m = elos_df['Club'].apply(lambda x: process.extract(x, s, limit=2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/Caskroom/miniconda/base/envs/footy/lib/python3.12/site-packages/fuzzywuzzy/process.py:108, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     106 try:
#     107     # See if choices is a dictionary-like object.
# --> 108     for key, choice in choices.items():
#     109         processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 4
#       2 s = clubs_df['name'].tolist()
#       3 s
# ----> 4 m = elos_df['Club'].apply(lambda x: process.extract(x, s, limit=2))
#
# ...

# %%
# Example usage of fuzzy_merge
df_result = fuzzy_merge(elos_df, clubs_df, 'Club', 'name' ,threshold=90, limit=2)
 
# Identify unmatched teams
df_unmatched = pd.concat([df_result['matches'], clubs_df['name']]).drop_duplicates(keep=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/Caskroom/miniconda/base/envs/footy/lib/python3.12/site-packages/fuzzywuzzy/process.py:108, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     106 try:
#     107     # See if choices is a dictionary-like object.
# --> 108     for key, choice in choices.items():
#     109         processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Example usage of fuzzy_merge
# ----> 2 df_result = fuzzy_merge(elos_df, clubs_df, 'Club', 'name' ,threshold=90, limit=2)
#       4 # Identify unmatched teams
# ...
